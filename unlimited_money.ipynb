# %%
print("hello world")
# Out:
# hello world

# %%
pip install instabot
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/84.4 kB ? eta -:--:--
#      -------------------------------------- - 81.9/84.4 kB 4.5 MB/s eta 0:00:01
#      -------------------------------------- 84.4/84.4 kB 950.4 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/46.7 kB ? eta -:--:--
# ...

# %%
pip install --upgrade Pillow
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\gsmob\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install instaloader
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\gsmob\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/65.4 kB ? eta -:--:--
#      ------------------------------------- -- 61.4/65.4 kB ? eta -:--:--
#      -------------------------------------- 65.4/65.4 kB 707.2 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for instaloader: filename=instaloader-4.13-py3-none-any.whl size=67518 sha256=7c59adb93ac15acf74c8a12b6b45caf88a1be294b438218ee063b6684acc17d0
# ...

# %%
pip  install instagrapi
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\gsmob\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/102.2 kB ? eta -:--:--
#      ----------------------------------- --- 92.2/102.2 kB 5.1 MB/s eta 0:00:01
#      ----------------------------------- --- 92.2/102.2 kB 5.1 MB/s eta 0:00:01
#      ------------------------------------ 102.2/102.2 kB 978.2 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
# ...

# %%
from instagrapi import Client

def upload_instagram_reel(username, password, video_path, description):
    try:
        # Initialize the Instagram Client
        cl = Client()

        # Login to Instagram
        cl.login(username, password)
        print("Logged in successfully!")

        # Upload the video with the description
        cl.clip_upload(video_path, caption=description)
        print("Reel uploaded successfully!")
    except Exception as e:
        print(f'An error occurred: {e}')

# Instagram credentials and video details
username = 'freaking_billionaire_4'  # Replace with your Instagram username
password = 'Uday@1011421'  # Replace with your Instagram password
video_path = r'C:\Users\gsmob\Downloads\surya bhai project\video.mp4'  # Replace with the path to your video file
description = '''Link in bio babe😉
#bedroomlighting #bedroomdecor #interiordesign 
#bedroomstyling #bedroominspo #lighting #bedroom 
#homedecor #bedroomideas #bedroomdesign 
#bedroomgoals #bedroominterior #chandelier 
#interior #masterbedroom #lightingdesign 
#bedroomstyle #ledlights #bedroominspiration 
#bedroomdecoration #bedroomdesignideas #design 
#livingroomlighting #bedroomwall #lightingideas 
#homelighting #cozybedroom #walllights #bedroomdecorating 
#modernlighting'''

# Run the upload function
upload_instagram_reel(username, password, video_path, description)
# Out:
# Logged in successfully!
# Analyzing CLIP file "C:\Users\gsmob\Downloads\surya bhai project\video.mp4"
# Generating thumbnail "C:\Users\gsmob\Downloads\surya bhai project\video.mp4.jpg"...
# Reel uploaded successfully!
